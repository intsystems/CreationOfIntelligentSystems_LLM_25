# %%
# !git clone https://github.com/baturaysaglam/llm-subspaces.git
# Out:
# Cloning into 'llm-subspaces'...
# remote: Enumerating objects: 6195, done.
# remote: Counting objects: 100% (4744/4744), done.
# remote: Compressing objects: 100% (3292/3292), done.
# remote: Total 6195 (delta 1215), reused 4524 (delta 1008), pack-reused 1451 (from 2)
# Receiving objects: 100% (6195/6195), 72.95 MiB | 5.05 MiB/s, done.
# Resolving deltas: 100% (1320/1320), done.
# Updating files: 100% (6053/6053), done.

# %%
from huggingface_hub import login
login('') # здесь твой hf токен
# %cd /content/llm-subspaces
# Out:
# /content/llm-subspaces

# %%
# !python hidden_state.py --model "openai-community/gpt2" --layer 12 --dataset arxiv --topic physics --batch_size 4 --num_samples 150 --max_tokens 128
# !python hidden_state.py --model "openai-community/gpt2" --layer 12 --dataset arxiv --topic math --batch_size 4 --num_samples 150 --max_tokens 128
# !python hidden_state.py --model "openai-community/gpt2" --layer 12 --dataset arxiv --topic stat --batch_size 4 --num_samples 150 --max_tokens 128

# !python hidden_state.py --model "Qwen/Qwen2.5-0.5b" --layer 12 --dataset arxiv --topic physics --batch_size 4 --num_samples 150 --max_tokens 128
# !python hidden_state.py --model "Qwen/Qwen2.5-0.5b" --layer 12 --dataset arxiv --topic math --batch_size 4 --num_samples 150 --max_tokens 128
# !python hidden_state.py --model "Qwen/Qwen2.5-0.5b" --layer 12 --dataset arxiv --topic stat --batch_size 4 --num_samples 150 --max_tokens 128

# !python hidden_state.py --model "Qwen/Qwen2.5-1.5b" --layer 12 --dataset arxiv --topic physics --batch_size 4 --num_samples 150 --max_tokens 128
# !python hidden_state.py --model "Qwen/Qwen2.5-1.5b" --layer 12 --dataset arxiv --topic math --batch_size 4 --num_samples 150 --max_tokens 128
# !python hidden_state.py --model "Qwen/Qwen2.5-1.5b" --layer 12 --dataset arxiv --topic stat --batch_size 4 --num_samples 150 --max_tokens 128

# !python hidden_state.py --model "Qwen/Qwen3-0.6B" --layer 12 --dataset arxiv --topic physics --batch_size 4 --num_samples 150 --max_tokens 128
# !python hidden_state.py --model "Qwen/Qwen3-0.6B" --layer 12 --dataset arxiv --topic math --batch_size 4 --num_samples 150 --max_tokens 128
# !python hidden_state.py --model "Qwen/Qwen3-0.6B" --layer 12 --dataset arxiv --topic stat --batch_size 4 --num_samples 150 --max_tokens 128

# !python hidden_state.py --model "Qwen/Qwen3-0.6B-Base" --layer 12 --dataset arxiv --topic physics --batch_size 4 --num_samples 150 --max_tokens 128
# !python hidden_state.py --model "Qwen/Qwen3-0.6B-Base" --layer 12 --dataset arxiv --topic math --batch_size 4 --num_samples 150 --max_tokens 128
# !python hidden_state.py --model "Qwen/Qwen3-0.6B-Base" --layer 12 --dataset arxiv --topic stat --batch_size 4 --num_samples 150 --max_tokens 128

# !python hidden_state.py --model "google/gemma-2b" --layer 12 --dataset arxiv --topic physics --batch_size 4 --num_samples 150 --max_tokens 128
# !python hidden_state.py --model "google/gemma-2b" --layer 12 --dataset arxiv --topic math --batch_size 4 --num_samples 150 --max_tokens 128
# !python hidden_state.py --model "google/gemma-2b" --layer 12 --dataset arxiv --topic stat --batch_size 4 --num_samples 150 --max_tokens 128

# !python hidden_state.py --model "google/gemma-3-1b-it" --layer 12 --dataset arxiv --topic physics --batch_size 4 --num_samples 150 --max_tokens 128
# !python hidden_state.py --model "google/gemma-3-1b-it" --layer 12 --dataset arxiv --topic math --batch_size 4 --num_samples 150 --max_tokens 128
# !python hidden_state.py --model "google/gemma-3-1b-it" --layer 12 --dataset arxiv --topic stat --batch_size 4 --num_samples 150 --max_tokens 128
# Out:
# config.json: 100% 665/665 [00:00<00:00, 5.19MB/s]
# `torch_dtype` is deprecated! Use `dtype` instead!
# 2025-11-06 13:13:19.605099: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:467] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1762434799.622519    5454 cuda_dnn.cc:8579] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1762434799.627315    5454 cuda_blas.cc:1407] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# W0000 00:00:1762434799.641530    5454 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# ...

# %%
# !python hidden_state.py --model "google/gemma-2b" --layer 12 --dataset arxiv --topic physics --batch_size 4 --num_samples 150 --max_tokens 128
# !python hidden_state.py --model "google/gemma-2b" --layer 12 --dataset arxiv --topic math --batch_size 4 --num_samples 150 --max_tokens 128
# !python hidden_state.py --model "google/gemma-2b" --layer 12 --dataset arxiv --topic stat --batch_size 4 --num_samples 150 --max_tokens 128

# !python hidden_state.py --model "google/gemma-3-1b-it" --layer 12 --dataset arxiv --topic physics --batch_size 4 --num_samples 150 --max_tokens 128
# !python hidden_state.py --model "google/gemma-3-1b-it" --layer 12 --dataset arxiv --topic math --batch_size 4 --num_samples 150 --max_tokens 128
# !python hidden_state.py --model "google/gemma-3-1b-it" --layer 12 --dataset arxiv --topic stat --batch_size 4 --num_samples 150 --max_tokens 128
# Out:
# config.json: 100% 627/627 [00:00<00:00, 4.57MB/s]
# `torch_dtype` is deprecated! Use `dtype` instead!
# 2025-11-06 13:24:42.146723: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:467] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1762435482.166498    8752 cuda_dnn.cc:8579] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1762435482.175252    8752 cuda_blas.cc:1407] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# W0000 00:00:1762435482.195531    8752 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# ...

# %%
# !python hidden_state.py --model "bigscience/bloom-1b1" --layer 12 --dataset arxiv --topic physics --batch_size 4 --num_samples 150 --max_tokens 128
# !python hidden_state.py --model "bigscience/bloom-1b1" --layer 12 --dataset arxiv --topic math --batch_size 4 --num_samples 150 --max_tokens 128
# !python hidden_state.py --model "bigscience/bloom-1b1" --layer 12 --dataset arxiv --topic stat --batch_size 4 --num_samples 150 --max_tokens 128

# !python hidden_state.py --model "bigscience/bloom-560m" --layer 12 --dataset arxiv --topic physics --batch_size 4 --num_samples 150 --max_tokens 128
# !python hidden_state.py --model "bigscience/bloom-560m" --layer 12 --dataset arxiv --topic math --batch_size 4 --num_samples 150 --max_tokens 128
# !python hidden_state.py --model "bigscience/bloom-560m" --layer 12 --dataset arxiv --topic stat --batch_size 4 --num_samples 150 --max_tokens 128
# Out:
# config.json: 100% 693/693 [00:00<00:00, 5.21MB/s]
# `torch_dtype` is deprecated! Use `dtype` instead!
# 2025-11-06 15:24:32.534347: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:467] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1762442672.551676   39072 cuda_dnn.cc:8579] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1762442672.556700   39072 cuda_blas.cc:1407] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# W0000 00:00:1762442672.572507   39072 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# ...

# %%
# %%writefile separability_final.py
import argparse
import numpy as np
import os
import glob
import torch
from sklearn.svm import LinearSVC
from sklearn.preprocessing import StandardScaler

def load_bf16_tensor(file_path):
    """Загрузка и конвертация BFloat16 тензора"""
    try:
        # Пробуем загрузить как есть
        data = torch.load(file_path)

        # Если это BFloat16 tensor, конвертируем в float32
        if isinstance(data, torch.Tensor) and data.dtype == torch.bfloat16:
            data = data.to(torch.float32)

        # Конвертируем в numpy
        if isinstance(data, torch.Tensor):
            data = data.cpu().numpy()

        return data
    except Exception as e:
        print(f"  Error loading {file_path}: {e}")
        # Пробуем альтернативный метод загрузки
        try:
            data = torch.load(file_path, map_location='cpu', weights_only=False)
            if isinstance(data, torch.Tensor) and data.dtype == torch.bfloat16:
                data = data.to(torch.float32)
            if isinstance(data, torch.Tensor):
                data = data.cpu().numpy()
            return data
        except Exception as e2:
            print(f"  Alternative load also failed: {e2}")
            return None

def load_hidden_states_simple(model, layer, dataset, topic):
    """Загрузка hidden states из .pt файлов с поддержкой BFloat16"""
    path = f"hidden_states/{model}/layer_{layer}/{dataset}/{topic}"
    print(f"Looking for data in: {path}")

    if not os.path.exists(path):
        print(f"Path does not exist: {path}")
        return None

    files = glob.glob(os.path.join(path, "*.pt"))
    if not files:
        print(f"No .pt files found in: {path}")
        return None

    print(f"Found {len(files)} .pt files for {topic}")

    hidden_states = []
    for file in sorted(files):
        data = load_bf16_tensor(file)
        if data is not None:
            hidden_states.append(data)
            print(f"  Loaded {file}: shape {data.shape}, dtype {data.dtype}")
        else:
            print(f"  Failed to load {file}")

    if hidden_states:
        combined = np.concatenate(hidden_states, axis=0)
        print(f"Combined shape for {topic}: {combined.shape}")
        return combined
    else:
        print(f"No valid data loaded for {topic}")
        return None

def main():
    parser = argparse.ArgumentParser()
    parser.add_argument("--model", type=str, required=True)
    parser.add_argument("--layer", type=int, required=True)
    parser.add_argument("--dataset", type=str, required=True)
    parser.add_argument("--topics", nargs=2, required=True)

    args = parser.parse_args()

    print("=" * 50)
    print(f"Testing linear separability")
    print(f"Model: {args.model}")
    print(f"Layer: {args.layer}")
    print(f"Dataset: {args.dataset}")
    print(f"Topics: {args.topics[0]} vs {args.topics[1]}")
    print("=" * 50)

    # Load data
    topic1_data = load_hidden_states_simple(args.model, args.layer, args.dataset, args.topics[0])
    topic2_data = load_hidden_states_simple(args.model, args.layer, args.dataset, args.topics[1])

    if topic1_data is None or topic2_data is None:
        print("ERROR: Could not load data for one or both topics")
        return

    # Check if we have enough samples
    if len(topic1_data) < 2 or len(topic2_data) < 2:
        print(f"ERROR: Not enough samples. {args.topics[0]}: {len(topic1_data)}, {args.topics[1]}: {len(topic2_data)}")
        return

    print(f"\nData loaded successfully!")
    print(f"{args.topics[0]} samples: {len(topic1_data)}")
    print(f"{args.topics[1]} samples: {len(topic2_data)}")

    # Prepare data for SVM
    X = np.concatenate([topic1_data, topic2_data], axis=0)
    y = np.concatenate([np.zeros(len(topic1_data)), np.ones(len(topic2_data))])

    print(f"Total samples: {len(X)}")
    print(f"Feature dimension: {X.shape[1]}")

    # Standardize
    scaler = StandardScaler()
    X_scaled = scaler.fit_transform(X)

    # Train SVM
    print("\nTraining SVM...")
    svm = LinearSVC(C=10e10, tol=1e-12, max_iter=10000, random_state=42)
    svm.fit(X_scaled, y)

    # Calculate accuracy
    accuracy = svm.score(X_scaled, y)

    print("\n" + "=" * 50)
    print("RESULTS:")
    print(f"Linear separability between {args.topics[0]} and {args.topics[1]}:")
    print(f"Accuracy: {accuracy:.4f}")
    print(f"SVM converged: {svm.n_iter_ < 10000}")
    print(f"Number of iterations: {svm.n_iter_}")

    if accuracy == 1.0:
        print("✅ Topics are LINEARLY SEPARABLE!")
    else:
        print("❌ Topics are NOT linearly separable")
    print("=" * 50)

if __name__ == "__main__":
    main()
# Out:
# Writing separability_final.py

# %%
# !python separability_final.py --model "gpt2" --layer 12 --dataset arxiv --topics physics math

# !python separability_final.py --model "qwen2.5-0.5b" --layer 12 --dataset arxiv --topics physics math
# !python separability_final.py --model "qwen2.5-1.5b" --layer 12 --dataset arxiv --topics physics math
# !python separability_final.py --model "qwen3-0.6b" --layer 12 --dataset arxiv --topics physics math
# !python separability_final.py --model "qwen3-0.6b-base" --layer 12 --dataset arxiv --topics physics math

# !python separability_final.py --model "gemma-2b" --layer 12 --dataset arxiv --topics physics math
# !python separability_final.py --model "gemma-3-1b-it" --layer 12 --dataset arxiv --topics physics math
# Out:
# ...
# Testing linear separability
# Model: gpt2
# Layer: 12
# Dataset: arxiv
# Topics: physics vs math
# ...
# Looking for data in: hidden_states/gpt2/layer_12/arxiv/physics
# Found 38 .pt files for physics
#   Loaded hidden_states/gpt2/layer_12/arxiv/physics/batch_0.pt: shape (4, 768), dtype float32
#   Loaded hidden_states/gpt2/layer_12/arxiv/physics/batch_1.pt: shape (4, 768), dtype float32
#   Loaded hidden_states/gpt2/layer_12/arxiv/physics/batch_10.pt: shape (4, 768), dtype float32
#   Loaded hidden_states/gpt2/layer_12/arxiv/physics/batch_11.pt: shape (4, 768), dtype float32
#   Loaded hidden_states/gpt2/layer_12/arxiv/physics/batch_12.pt: shape (4, 768), dtype float32
#   Loaded hidden_states/gpt2/layer_12/arxiv/physics/batch_13.pt: shape (4, 768), dtype float32
#   Loaded hidden_states/gpt2/layer_12/arxiv/physics/batch_14.pt: shape (4, 768), dtype float32
#   Loaded hidden_states/gpt2/layer_12/arxiv/physics/batch_15.pt: shape (4, 768), dtype float32
# ...

# %% [markdown]
# # Gemma почему-то не смогла разделить физику и математику

# %%
import numpy as np
import torch
import matplotlib.pyplot as plt
from sklearn.decomposition import PCA
import os

def safe_tensor_load(file_path):
    """Безопасная загрузка тензора с любым dtype"""
    try:
        # Загружаем на CPU
        tensor = torch.load(file_path, map_location='cpu')

        # Конвертируем в float32 если нужно
        if tensor.dtype in [torch.bfloat16, torch.float16]:
            tensor = tensor.to(torch.float32)

        return tensor.numpy()
    except Exception as e:
        print(f"Error loading {file_path}: {e}")
        return None

def load_and_convert_tensor(file_path):
    """Загружает и конвертирует тензор в float32"""
    data = torch.load(file_path, map_location='cpu')
    if data.dtype == torch.bfloat16:
        data = data.to(torch.float32)
    return data.numpy()

# %%
def get_plots(physics_path, math_path, stat_path, model_name):
  physics_data = []
  math_data = []
  stat_data = []

  # Physics
  for file in sorted(os.listdir(physics_path)):
      if file.endswith('.pt'):
          data = load_and_convert_tensor(os.path.join(physics_path, file))
          physics_data.append(data)

  # Math
  for file in sorted(os.listdir(math_path)):
      if file.endswith('.pt'):
          data = load_and_convert_tensor(os.path.join(math_path, file))
          math_data.append(data)

  # Statistics
  for file in sorted(os.listdir(stat_path)):
      if file.endswith('.pt'):
          data = load_and_convert_tensor(os.path.join(stat_path, file))
          stat_data.append(data)

  physics_combined = np.concatenate(physics_data, axis=0)
  math_combined = np.concatenate(math_data, axis=0)
  stat_combined = np.concatenate(stat_data, axis=0)

  X = np.concatenate([physics_combined, math_combined, stat_combined], axis=0)
  y = np.concatenate([
    np.zeros(len(physics_combined)),           # physics = 0
    np.ones(len(math_combined)),              # math = 1
    np.full(len(stat_combined), 2)            # stat = 2
  ])

  pca_3d = PCA(n_components=3)
  X_pca_3d = pca_3d.fit_transform(X)

  fig = plt.figure(figsize=(14, 10))
  ax = fig.add_subplot(111, projection='3d')


  scatter1 = ax.scatter(X_pca_3d[y == 0, 0], X_pca_3d[y == 0, 1], X_pca_3d[y == 0, 2],
                       alpha=0.8, label='Physics', color='red', s=60, marker='o')

  scatter2 = ax.scatter(X_pca_3d[y == 1, 0], X_pca_3d[y == 1, 1], X_pca_3d[y == 1, 2],
                       alpha=0.8, label='Math', color='blue', s=60, marker='^')

  scatter3 = ax.scatter(X_pca_3d[y == 2, 0], X_pca_3d[y == 2, 1], X_pca_3d[y == 2, 2],
                       alpha=0.8, label='Statistics', color='green', s=60, marker='s')

  ax.set_xlabel(f'PC1 ({pca_3d.explained_variance_ratio_[0]:.2%})')
  ax.set_ylabel(f'PC2 ({pca_3d.explained_variance_ratio_[1]:.2%})')
  ax.set_zlabel(f'PC3 ({pca_3d.explained_variance_ratio_[2]:.2%})')
  title = '3D PCA: Physics vs Math vs Statistics\n(' + model_name + ', Layer 12)'
  ax.set_title(title)
  ax.legend()
  plt.tight_layout()
  plt.show()




  physics_cluster_center = np.mean(X_pca_3d[y == 0], axis=0)
  math_cluster_center = np.mean(X_pca_3d[y == 1], axis=0)
  stat_cluster_center = np.mean(X_pca_3d[y == 2], axis=0)

  return physics_cluster_center, math_cluster_center, stat_cluster_center, pca_3d.explained_variance_ratio_, pca_3d.explained_variance_ratio_.sum()

# %%
models = ["gpt2", "qwen2.5-0.5b", "qwen2.5-1.5b", "qwen3-0.6b", "qwen3-0.6b-base", "gemma-2b", "gemma-3-1b-it", "bloom-560m", "bloom-1b1"]
datas = []

for m in models:
  physics_path = "hidden_states/" + m + "/layer_12/arxiv/physics"
  math_path = "hidden_states/" + m + "/layer_12/arxiv/math"
  stat_path = "hidden_states/" + m + "/layer_12/arxiv/stat"

  datas.append(get_plots(physics_path, math_path, stat_path, m))

# %%
plt.plot(models, [i[3][0] for i in datas], label = r"$\lambda_1$")
plt.plot(models, [i[3][1] for i in datas], label = r"$\lambda_2$")
plt.plot(models, [i[3][2] for i in datas], label = r"$\lambda_3$")

plt.title('График доли объяснённой дисперсии')
plt.xticks(rotation=45, ha="right")
plt.xlabel('название модели')
plt.legend()
plt.grid()

# %%
def metric(x1, x2):
  return np.sqrt((x1[0] - x2[0]) ** 2 + (x1[1] - x2[1]) ** 2 + (x1[2] - x2[2]) ** 2)

plt.plot(models, [metric(i[0], i[1]) for i in datas], label = "между физикой и математикой")
plt.plot(models, [metric(i[0], i[2]) for i in datas], label = "между физикой и статистикой")
plt.plot(models, [metric(i[2], i[1]) for i in datas], label = "между статистикой и математикой")

plt.title('График расстояний')
plt.xticks(rotation=45, ha="right")
plt.xlabel('название модели')
plt.legend()
plt.grid()

# %%
plt.plot(models, [min(100, metric(i[0], i[1])) for i in datas], label = "между физикой и математикой")
plt.plot(models, [min(100, metric(i[0], i[2])) for i in datas], label = "между физикой и статистикой")
plt.plot(models, [min(metric(i[2], i[1]), 100) for i in datas], label = "между статистикой и математикой")

plt.title('График расстояний')
plt.xticks(rotation=45, ha="right")
plt.xlabel('название модели')
plt.legend()
plt.grid()

# %% [markdown]
# Расстояния между центрами кластеров PCA скрытых состояний, соответствующим разным топикам, на одном и том же 12 слое, различаются в зависимости от моделей. Но отношения одинаковые
#
# Какая бы модель ни была:
#   - расстояние между статистикой и математикой > расстояние между физикой и математикой > расстояние между физикой и статистикой
